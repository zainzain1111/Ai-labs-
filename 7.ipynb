# %%
# -*- coding: utf-8 -*-
"""l01c01_introduction_to_colab_and_python.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l01c01_introduction_to_colab_and_python.ipynb
"""

# LAB TASK 1: Next Word Prediction using RNN

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# Sample text dataset
text = """
the sun is shining
the sun is bright
the weather is good
the sky is blue
"""

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

# Padding
max_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# Build RNN Model
model = Sequential([
    Embedding(total_words, 10, input_length=max_len-1),
    SimpleRNN(64),
    Dense(total_words, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()

# Train model
model.fit(X, y, epochs=300, verbose=0)

# Test prediction
seed_text = "the sun is"
token_list = tokenizer.texts_to_sequences([seed_text])[0]
token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')

predicted = model.predict(token_list)
predicted_word = tokenizer.index_word[np.argmax(predicted)]

print("Input:", seed_text)
print("Predicted Next Word:", predicted_word)

# LAB TASK 3: Sentiment Analysis using RNN

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# Load dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)

# Padding
X_train = pad_sequences(X_train, maxlen=200)
X_test = pad_sequences(X_test, maxlen=200)

# Build model
model = Sequential([
    Embedding(10000, 32, input_length=200),
    SimpleRNN(32),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=128)

# Evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)

# LAB TASK 5: Music Note Generation using RNN

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Sample music notes (encoded)
notes = [60, 62, 64, 65, 67, 69, 71, 72] * 20

# Prepare sequences
X, y = [], []
for i in range(10, len(notes)):
    X.append(notes[i-10:i])
    y.append(notes[i])

X, y = np.array(X), np.array(y)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build model
model = Sequential([
    SimpleRNN(50, input_shape=(10,1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=50)

# Generate new notes
seed = notes[:10]
generated = seed.copy()

for _ in range(10):
    x = np.array(generated[-10:]).reshape(1,10,1)
    next_note = int(model.predict(x)[0][0])
    generated.append(next_note)

print("Generated Music Notes:", generated)



# LAB TASK 4: Weather Forecasting using RNN

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Synthetic temperature data
data = np.sin(np.arange(0, 1000) * 0.02) + np.random.normal(0, 0.1, 1000)

# Prepare sequences
X, y = [], []
for i in range(30, len(data)):
    X.append(data[i-30:i])
    y.append(data[i])

X, y = np.array(X), np.array(y)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build model
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_8 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Input: the sun is
# Predicted Next Word: bright
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.5286 - loss: 0.6894
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7332 - loss: 0.5593
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8924 - loss: 0.2770
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9572 - loss: 0.1361
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9831 - loss: 0.0671
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8410 - loss: 0.4994
# Test Accuracy: 0.8430399894714355
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - loss: 4425.7109
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4372.3594
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4313.3062
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4300.0425
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4253.1279
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4225.6353
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4123.8828
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4077.1741
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4110.6636
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3963.0144
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3970.5481
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3863.5808
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3806.1746
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3797.2227
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3731.4175
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3700.3489
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3621.4546
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3637.0559
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3593.6675
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3568.7815
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3488.6768
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3526.1326
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3494.8337
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3454.9014
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3434.7458
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3371.4954
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3379.4312
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3294.3894
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3298.8030
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3287.5610
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3246.4570
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3229.8623
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3191.7905
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3175.5713
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3111.3350
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3152.5725
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3101.0168
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3061.4448
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3026.9514
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3009.0298
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2960.1174
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2948.7515
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2925.2380
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2902.5901
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2870.1196
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2863.3914
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2787.5786
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2804.6277
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2748.4487
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2750.2988
# WARNING:tensorflow:5 out of the last 155 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7beac79b7420> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Generated Music Notes: [60, 62, 64, 65, 67, 69, 71, 72, 60, 62, 14, 13, 13, 13, 13, 13, 13, 13, 13, 13]
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.2477
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0256
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0166
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0167
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0159
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0148
# Epoch 8/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142
# Epoch 9/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0161
# Epoch 10/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0139
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
model = Sequential([
    SimpleRNN(50, input_shape=(30,1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=10)

# Predict
pred = model.predict(X)

# Plot
plt.plot(y, label='Actual')
plt.plot(pred, label='Predicted')
plt.legend()
plt.show()
